# %%
import numpy as np
import pandas as pd
import networkx as nx
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import laplacian
from scipy.sparse.linalg import eigsh
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Gewichtungsfaktoren
risk_weights = {
    "both": 393,
    "one": 18,
    "none": 2,
}

# Daten bereinigen
def clean_preferences(preferences_df):
    preferences_df = preferences_df.fillna(0)  # Fehlende Werte mit 0 auffüllen
    return preferences_df.astype(int)  # Alles in Integer konvertieren

# Gewicht für eine Kante berechnen
def calculate_edge_weight(user1, user2, preferences_df):
    try:
        # Prüfe, ob Präferenzdaten existieren
        if user1 not in preferences_df.index or user2 not in preferences_df.index:
            raise ValueError(f"Präferenzdaten fehlen für Benutzer {user1} oder {user2}.")

        # Konvertiere Präferenzen in Binärdaten
        genres_user1 = np.array(preferences_df.loc[user1].values, dtype=int)
        genres_user2 = np.array(preferences_df.loc[user2].values, dtype=int)

        # Sichere Bit-Operationen
        common_genres = np.sum(genres_user1 & genres_user2)
        one_sided_genres = np.sum(genres_user1 ^ genres_user2)
        neither_genres = len(genres_user1) - (common_genres + one_sided_genres)

        # Begrenze extrem hohe Werte
        max_genres = 1e3  # Beispiel-Grenzwert
        common_genres = min(common_genres, max_genres)
        one_sided_genres = min(one_sided_genres, max_genres)
        neither_genres = max(0, len(genres_user1) - (common_genres + one_sided_genres))

        # Kanten-Gewicht berechnen
        weight = (
            risk_weights["both"] * common_genres +
            risk_weights["one"] * one_sided_genres +
            risk_weights["none"] * neither_genres
        )
        return weight
    except Exception as e:
        print(f"Fehler beim Berechnen des Gewichts für Kante ({user1}, {user2}): {e}")
        return 0



# Netzwerk und Präferenzen laden
friends_df = pd.read_csv('friends.csv', delimiter=',', header=None)
G = nx.Graph()
G.add_edges_from(friends_df.values)
print(f"Netzwerk erstellt: {G.number_of_nodes()} Knoten, {G.number_of_edges()} Kanten")

preferences_df = pd.read_json('preferences.json', orient='index')
preferences_df = clean_preferences(preferences_df)

# Kanten mit Gewichten versehen
print("Berechnung der Kanten-Gewichte...")
weighted_edges = []
for user1, user2 in G.edges():
    weight = calculate_edge_weight(user1, user2, preferences_df)
    weighted_edges.append((user1, user2, weight))

G.add_weighted_edges_from(weighted_edges)

# Laplace-Matrix berechnen
print("Berechnung der Laplace-Matrix...")
A_sparse = nx.to_scipy_sparse_array(G, format="csr")
L_sparse = laplacian(A_sparse, normed=True)

# Spektrale Analyse
print("Berechnung der Eigenwerte und Eigenvektoren...")
k = 10  # Clusteranzahl
eigvals, eigvecs = eigsh(L_sparse, k=k+1, which="SM")
embedding = eigvecs[:, 1:k+1]  # Erste Spalte (triviale Lösung) überspringen

# K-Means-Clustering
print("Clustering der Benutzer...")
kmeans = KMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(embedding)

# Degree Centrality
print("Berechnung der Degree Centrality...")
degree_centrality = nx.degree_centrality(G)

# Auswahl der wichtigsten Knoten
print("Auswahl der Impfkandidaten...")
cluster_nodes = {i: [] for i in range(k)}
for node, cluster in zip(G.nodes(), clusters):
    cluster_nodes[cluster].append((node, degree_centrality[node]))

selected_nodes = []
for cluster, nodes in cluster_nodes.items():
    nodes = sorted(nodes, key=lambda x: x[1], reverse=True)  # Sortiere nach Degree Centrality
    selected_nodes.extend([node for node, _ in nodes[:int(997 / k)]])

# Ergebnisse speichern
with open("selected_vaccination_nodes.txt", "w") as f:
    for node in selected_nodes:
        f.write(f"{node}\n")
print(f"Ausgewählte Knoten gespeichert: {len(selected_nodes)} Knoten.")

# Visualisierung
pos = nx.spring_layout(G, seed=42)
colors = ['red' if node in selected_nodes else 'blue' for node in G.nodes()]
plt.figure(figsize=(12, 8))
nx.draw(G, pos, node_color=colors, node_size=10, edge_color='gray', alpha=0.7)
plt.title("Netzwerkvisualisierung mit hervorgehobenen Teilnehmern")
plt.show()
# Out:
# Netzwerk erstellt: 8311 Knoten, 55483 Kanten
# Berechnung der Kanten-Gewichte...
# Warnung: Extreme Werte für Kante (360, 4719).
# Warnung: Extreme Werte für Kante (360, 4720).
# Warnung: Extreme Werte für Kante (360, 4721).
# Warnung: Extreme Werte für Kante (360, 4722).
# Warnung: Extreme Werte für Kante (360, 14).
# Warnung: Extreme Werte für Kante (360, 4723).
# Warnung: Extreme Werte für Kante (360, 1020).
# Warnung: Extreme Werte für Kante (360, 4724).
# Warnung: Extreme Werte für Kante (360, 4725).
# Warnung: Extreme Werte für Kante (360, 4726).
# Warnung: Extreme Werte für Kante (360, 4727).
# Warnung: Extreme Werte für Kante (360, 4728).
# Warnung: Extreme Werte für Kante (360, 4729).
# Warnung: Extreme Werte für Kante (360, 1286).
# Warnung: Extreme Werte für Kante (360, 4730).
# Warnung: Extreme Werte für Kante (360, 4731).
# Warnung: Extreme Werte für Kante (360, 4732).
# Warnung: Extreme Werte für Kante (360, 4733).
# Warnung: Extreme Werte für Kante (360, 4734).
# Warnung: Extreme Werte für Kante (360, 4735).
# Warnung: Extreme Werte für Kante (360, 4736).
# Warnung: Extreme Werte für Kante (360, 4737).
# Warnung: Extreme Werte für Kante (360, 1075).
# Warnung: Extreme Werte für Kante (4719, 4940).
# Warnung: Extreme Werte für Kante (4719, 7818).
# Warnung: Extreme Werte für Kante (4719, 6307).
# Warnung: Extreme Werte für Kante (4719, 6277).
# Warnung: Extreme Werte für Kante (4719, 4724).
# Warnung: Extreme Werte für Kante (4719, 4722).
# Warnung: Extreme Werte für Kante (4720, 2220).
# Warnung: Extreme Werte für Kante (4720, 4944).
# Warnung: Extreme Werte für Kante (4720, 6263).
# Warnung: Extreme Werte für Kante (4720, 890).
# Warnung: Extreme Werte für Kante (4720, 4955).
# Warnung: Extreme Werte für Kante (4720, 3524).
# Warnung: Extreme Werte für Kante (4720, 4961).
# Warnung: Extreme Werte für Kante (4720, 4968).
# Warnung: Extreme Werte für Kante (4720, 4979).
# Warnung: Extreme Werte für Kante (4720, 6286).
# Warnung: Extreme Werte für Kante (4720, 377).
# Warnung: Extreme Werte für Kante (4720, 1783).
# Warnung: Extreme Werte für Kante (4720, 4991).
# Warnung: Extreme Werte für Kante (4720, 6336).
# Warnung: Extreme Werte für Kante (4720, 4982).
# Warnung: Extreme Werte für Kante (4720, 1851).
# Warnung: Extreme Werte für Kante (4720, 5001).
# Warnung: Extreme Werte für Kante (4721, 1337).
# Warnung: Extreme Werte für Kante (4721, 429).
# Warnung: Extreme Werte für Kante (4721, 5782).
# Warnung: Extreme Werte für Kante (4722, 2220).
# Warnung: Extreme Werte für Kante (4722, 4940).
# Warnung: Extreme Werte für Kante (4722, 4732).
# Warnung: Extreme Werte für Kante (4722, 4729).
# Warnung: Extreme Werte für Kante (4722, 7424).
# Warnung: Extreme Werte für Kante (4722, 4908).
# Warnung: Extreme Werte für Kante (4722, 4723).
# Warnung: Extreme Werte für Kante (4722, 1794).
# Warnung: Extreme Werte für Kante (4722, 4101).
# Warnung: Extreme Werte für Kante (4722, 4724).
# Warnung: Extreme Werte für Kante (14, 243).
# Warnung: Extreme Werte für Kante (14, 1).
# Warnung: Extreme Werte für Kante (14, 361).
# Warnung: Extreme Werte für Kante (14, 362).
# Warnung: Extreme Werte für Kante (14, 3).
# Warnung: Extreme Werte für Kante (14, 363).
# Warnung: Extreme Werte für Kante (14, 364).
# Warnung: Extreme Werte für Kante (14, 365).
# Warnung: Extreme Werte für Kante (14, 96).
# Warnung: Extreme Werte für Kante (14, 366).
# Warnung: Extreme Werte für Kante (14, 367).
# Warnung: Extreme Werte für Kante (14, 368).
# Warnung: Extreme Werte für Kante (14, 265).
# Warnung: Extreme Werte für Kante (14, 369).
# Warnung: Extreme Werte für Kante (14, 370).
# Warnung: Extreme Werte für Kante (14, 371).
# Warnung: Extreme Werte für Kante (14, 372).
# Warnung: Extreme Werte für Kante (14, 325).
# Warnung: Extreme Werte für Kante (14, 373).
# Warnung: Extreme Werte für Kante (14, 32).
# Warnung: Extreme Werte für Kante (14, 374).
# Warnung: Extreme Werte für Kante (14, 328).
# Warnung: Extreme Werte für Kante (14, 199).
# Warnung: Extreme Werte für Kante (14, 375).
# Warnung: Extreme Werte für Kante (14, 69).
# Warnung: Extreme Werte für Kante (14, 376).
# Warnung: Extreme Werte für Kante (14, 377).
# Warnung: Extreme Werte für Kante (14, 378).
# Warnung: Extreme Werte für Kante (14, 286).
# Warnung: Extreme Werte für Kante (14, 379).
# Warnung: Extreme Werte für Kante (14, 36).
# Warnung: Extreme Werte für Kante (14, 106).
# Warnung: Extreme Werte für Kante (14, 79).
# Warnung: Extreme Werte für Kante (14, 95).
# Warnung: Extreme Werte für Kante (14, 0).
# Warnung: Extreme Werte für Kante (14, 87).
# Warnung: Extreme Werte für Kante (14, 22).
# Warnung: Extreme Werte für Kante (14, 64).
# Warnung: Extreme Werte für Kante (14, 380).
# Warnung: Extreme Werte für Kante (14, 24).
# Warnung: Extreme Werte für Kante (14, 381).
# Warnung: Extreme Werte für Kante (14, 382).
# Warnung: Extreme Werte für Kante (14, 383).
# Warnung: Extreme Werte für Kante (14, 317).
# Warnung: Extreme Werte für Kante (14, 384).
# Warnung: Extreme Werte für Kante (14, 385).
# Warnung: Extreme Werte für Kante (14, 74).
# Warnung: Extreme Werte für Kante (14, 191).
# Warnung: Extreme Werte für Kante (14, 386).
# Warnung: Extreme Werte für Kante (14, 387).
# Warnung: Extreme Werte für Kante (14, 19).
# Warnung: Extreme Werte für Kante (14, 388).
# Warnung: Extreme Werte für Kante (14, 389).
# Warnung: Extreme Werte für Kante (14, 20).
# Warnung: Extreme Werte für Kante (14, 390).
# Warnung: Extreme Werte für Kante (14, 391).
# Warnung: Extreme Werte für Kante (4723, 1801).
# Warnung: Extreme Werte für Kante (4723, 4732).
# Warnung: Extreme Werte für Kante (4723, 4955).
# Warnung: Extreme Werte für Kante (4723, 4907).
# Warnung: Extreme Werte für Kante (4723, 4969).
# Warnung: Extreme Werte für Kante (4723, 6333).
# Warnung: Extreme Werte für Kante (4723, 6344).
# Warnung: Extreme Werte für Kante (4723, 5948).
# Warnung: Extreme Werte für Kante (4723, 4997).
# Warnung: Extreme Werte für Kante (4723, 6336).
# Warnung: Extreme Werte für Kante (4723, 5001).
# Warnung: Extreme Werte für Kante (1020, 1512).
# Warnung: Extreme Werte für Kante (1020, 2729).
# Warnung: Extreme Werte für Kante (1020, 984).
# Warnung: Extreme Werte für Kante (1020, 1019).
# Warnung: Extreme Werte für Kante (1020, 1025).
# Warnung: Extreme Werte für Kante (1020, 51).
# Warnung: Extreme Werte für Kante (1020, 996).
# Warnung: Extreme Werte für Kante (1020, 3188).
# Warnung: Extreme Werte für Kante (1020, 3778).
# Warnung: Extreme Werte für Kante (1020, 7285).
# Warnung: Extreme Werte für Kante (1020, 887).
# Warnung: Extreme Werte für Kante (1020, 3664).
# Warnung: Extreme Werte für Kante (1020, 6069).
# Warnung: Extreme Werte für Kante (1020, 757).
# Warnung: Extreme Werte für Kante (1020, 3579).
# Warnung: Extreme Werte für Kante (1020, 1296).
# Warnung: Extreme Werte für Kante (1020, 1687).
# Warnung: Extreme Werte für Kante (1020, 2230).
# Warnung: Extreme Werte für Kante (1020, 769).
# Warnung: Extreme Werte für Kante (1020, 2163).
# Warnung: Extreme Werte für Kante (1020, 1167).
# Warnung: Extreme Werte für Kante (1020, 748).
# Warnung: Extreme Werte für Kante (1020, 816).
# Warnung: Extreme Werte für Kante (1020, 1030).
# Warnung: Extreme Werte für Kante (1020, 3855).
# Warnung: Extreme Werte für Kante (4724, 4732).
# Warnung: Extreme Werte für Kante (4724, 6268).
# Warnung: Extreme Werte für Kante (4724, 3754).
# Warnung: Extreme Werte für Kante (4725, 795).
# Warnung: Extreme Werte für Kante (4725, 2591).
# Warnung: Extreme Werte für Kante (4725, 963).
# Warnung: Extreme Werte für Kante (4725, 794).
# Warnung: Extreme Werte für Kante (4725, 2272).
# Warnung: Extreme Werte für Kante (4726, 8189).
# Warnung: Extreme Werte für Kante (4726, 5585).
# Warnung: Extreme Werte für Kante (4726, 3818).
# Warnung: Extreme Werte für Kante (4726, 5220).
# Warnung: Extreme Werte für Kante (4726, 2801).
# Warnung: Extreme Werte für Kante (4726, 3820).
# Warnung: Extreme Werte für Kante (4726, 7447).
# Warnung: Extreme Werte für Kante (4726, 3774).
# Warnung: Extreme Werte für Kante (4726, 6998).
# Warnung: Extreme Werte für Kante (4726, 7452).
# Warnung: Extreme Werte für Kante (4726, 7252).
# Warnung: Extreme Werte für Kante (4726, 7450).
# Warnung: Extreme Werte für Kante (4726, 3208).
# Warnung: Extreme Werte für Kante (4726, 7292).
# Warnung: Extreme Werte für Kante (4726, 7359).
# Warnung: Extreme Werte für Kante (4726, 542).
# Warnung: Extreme Werte für Kante (4726, 5627).
# Warnung: Extreme Werte für Kante (4726, 3561).
# Warnung: Extreme Werte für Kante (4726, 7258).
# Warnung: Extreme Werte für Kante (4726, 7265).
# Warnung: Extreme Werte für Kante (4726, 3666).
# Warnung: Extreme Werte für Kante (4726, 4812).
# Warnung: Extreme Werte für Kante (4726, 7253).
# Warnung: Extreme Werte für Kante (4726, 7438).
# Warnung: Extreme Werte für Kante (4726, 7287).
# Warnung: Extreme Werte für Kante (4726, 7255).
# Warnung: Extreme Werte für Kante (4726, 3897).
# Warnung: Extreme Werte für Kante (4726, 7060).
# Warnung: Extreme Werte für Kante (4726, 5234).
# Warnung: Extreme Werte für Kante (4726, 7990).
# Warnung: Extreme Werte für Kante (4726, 3833).
# Warnung: Extreme Werte für Kante (4726, 7062).
# Warnung: Extreme Werte für Kante (4726, 7261).
# Warnung: Extreme Werte für Kante (4726, 7249).
# Warnung: Extreme Werte für Kante (4728, 1106).
# Warnung: Extreme Werte für Kante (4728, 7421).
# Warnung: Extreme Werte für Kante (4728, 2094).
# Warnung: Extreme Werte für Kante (4728, 1218).
# Warnung: Extreme Werte für Kante (4728, 372).
# Warnung: Extreme Werte für Kante (4728, 4908).
# Warnung: Extreme Werte für Kante (4728, 1687).
# Warnung: Extreme Werte für Kante (4728, 785).
# Warnung: Extreme Werte für Kante (4728, 830).
# Warnung: Extreme Werte für Kante (4728, 6292).
# Warnung: Extreme Werte für Kante (4728, 1701).
# Warnung: Extreme Werte für Kante (4728, 2089).
# Warnung: Extreme Werte für Kante (4728, 4060).
# Warnung: Extreme Werte für Kante (4728, 6336).
# Warnung: Extreme Werte für Kante (4728, 2098).
# Warnung: Extreme Werte für Kante (4728, 3081).
# Warnung: Extreme Werte für Kante (4728, 1867).
# Warnung: Extreme Werte für Kante (4728, 951).
# Warnung: Extreme Werte für Kante (4729, 4955).
# Warnung: Extreme Werte für Kante (4729, 4977).
# Warnung: Extreme Werte für Kante (4729, 377).
# Warnung: Extreme Werte für Kante (1286, 8255).
# Warnung: Extreme Werte für Kante (1286, 1107).
# Warnung: Extreme Werte für Kante (1286, 4903).
# Warnung: Extreme Werte für Kante (1286, 1762).
# Warnung: Extreme Werte für Kante (1286, 3842).
# Warnung: Extreme Werte für Kante (1286, 4943).
# Warnung: Extreme Werte für Kante (1286, 985).
# Warnung: Extreme Werte für Kante (1286, 448).
# Warnung: Extreme Werte für Kante (1286, 7374).
# Warnung: Extreme Werte für Kante (1286, 6096).
# Warnung: Extreme Werte für Kante (1286, 6078).
# Warnung: Extreme Werte für Kante (1286, 2230).
# Warnung: Extreme Werte für Kante (1286, 5908).
# Warnung: Extreme Werte für Kante (1286, 83).
# Warnung: Extreme Werte für Kante (1286, 538).
# Warnung: Extreme Werte für Kante (1286, 1112).
# Warnung: Extreme Werte für Kante (1286, 5026).
# Warnung: Extreme Werte für Kante (1286, 3803).
# Warnung: Extreme Werte für Kante (1286, 2766).
# Warnung: Extreme Werte für Kante (1286, 1687).
# Warnung: Extreme Werte für Kante (1286, 1688).
# Warnung: Extreme Werte für Kante (1286, 5999).
# Warnung: Extreme Werte für Kante (1286, 1010).
# Warnung: Extreme Werte für Kante (1286, 1819).
# Warnung: Extreme Werte für Kante (1286, 388).
# Warnung: Extreme Werte für Kante (1286, 551).
# Warnung: Extreme Werte für Kante (1286, 1702).
# Warnung: Extreme Werte für Kante (1286, 1167).
# Warnung: Extreme Werte für Kante (1286, 3764).
# Warnung: Extreme Werte für Kante (1286, 1040).
# Warnung: Extreme Werte für Kante (1286, 3873).
# Warnung: Extreme Werte für Kante (1286, 1007).
# Warnung: Extreme Werte für Kante (1286, 768).
# Warnung: Extreme Werte für Kante (1286, 5938).
# Warnung: Extreme Werte für Kante (1286, 1082).
# Warnung: Extreme Werte für Kante (1286, 783).
# Warnung: Extreme Werte für Kante (1286, 1000).
# Warnung: Extreme Werte für Kante (1286, 5927).
# Warnung: Extreme Werte für Kante (1286, 816).
# Warnung: Extreme Werte für Kante (1286, 4350).
# Warnung: Extreme Werte für Kante (1286, 4807).
# Warnung: Extreme Werte für Kante (1286, 3752).
# Warnung: Extreme Werte für Kante (1286, 1363).
# Warnung: Extreme Werte für Kante (1286, 1251).
# Warnung: Extreme Werte für Kante (1286, 1096).
# Warnung: Extreme Werte für Kante (1286, 377).
# Warnung: Extreme Werte für Kante (1286, 3504).
# Warnung: Extreme Werte für Kante (1286, 2804).
# Warnung: Extreme Werte für Kante (1286, 1415).
# Warnung: Extreme Werte für Kante (1286, 5024).
# Warnung: Extreme Werte für Kante (1286, 2264).
# Warnung: Extreme Werte für Kante (1286, 1307).
# Warnung: Extreme Werte für Kante (1286, 1031).
# Warnung: Extreme Werte für Kante (1286, 942).
# Warnung: Extreme Werte für Kante (1286, 4731).
# Warnung: Extreme Werte für Kante (1286, 1089).
# Warnung: Extreme Werte für Kante (1286, 156).
# Warnung: Extreme Werte für Kante (1286, 1432).
# Warnung: Extreme Werte für Kante (1286, 3887).
# Warnung: Extreme Werte für Kante (1286, 1474).
# Warnung: Extreme Werte für Kante (1286, 1793).
# Warnung: Extreme Werte für Kante (1286, 3407).
# Warnung: Extreme Werte für Kante (1286, 2601).
# Warnung: Extreme Werte für Kante (1286, 7634).
# Warnung: Extreme Werte für Kante (1286, 6116).
# Warnung: Extreme Werte für Kante (1286, 1586).
# Warnung: Extreme Werte für Kante (1286, 3727).
# Warnung: Extreme Werte für Kante (1286, 3492).
# Warnung: Extreme Werte für Kante (1286, 548).
# Warnung: Extreme Werte für Kante (1286, 1003).
# Warnung: Extreme Werte für Kante (1286, 2117).
# Warnung: Extreme Werte für Kante (1286, 3541).
# Warnung: Extreme Werte für Kante (1286, 366).
# Warnung: Extreme Werte für Kante (1286, 1413).
# Warnung: Extreme Werte für Kante (1286, 6963).
# Warnung: Extreme Werte für Kante (1286, 1396).
# Warnung: Extreme Werte für Kante (1286, 2037).
# Warnung: Extreme Werte für Kante (1286, 2370).
# Warnung: Extreme Werte für Kante (1286, 1296).
# Warnung: Extreme Werte für Kante (1286, 6088).
# Warnung: Extreme Werte für Kante (1286, 786).
# Warnung: Extreme Werte für Kante (1286, 73).
# Warnung: Extreme Werte für Kante (1286, 3089).
# Warnung: Extreme Werte für Kante (1286, 2163).
# Warnung: Extreme Werte für Kante (1286, 936).
# Warnung: Extreme Werte für Kante (1286, 2796).
# Warnung: Extreme Werte für Kante (1286, 3778).
# Warnung: Extreme Werte für Kante (1286, 3489).
# Warnung: Extreme Werte für Kante (1286, 6731).
# Warnung: Extreme Werte für Kante (1286, 3491).
# Warnung: Extreme Werte für Kante (1286, 775).
# Warnung: Extreme Werte für Kante (1286, 5036).
# Warnung: Extreme Werte für Kante (4730, 1333).
# Warnung: Extreme Werte für Kante (4730, 1044).
# Warnung: Extreme Werte für Kante (4730, 5367).
# Warnung: Extreme Werte für Kante (4730, 1511).
# Warnung: Extreme Werte für Kante (4730, 3382).
# Warnung: Extreme Werte für Kante (4730, 4801).
# Warnung: Extreme Werte für Kante (4730, 398).
# Warnung: Extreme Werte für Kante (4730, 5338).
# Warnung: Extreme Werte für Kante (4730, 4527).
# Warnung: Extreme Werte für Kante (4730, 7326).
# Warnung: Extreme Werte für Kante (4730, 5733).
# Warnung: Extreme Werte für Kante (4731, 1167).
# Warnung: Extreme Werte für Kante (4731, 777).
# Warnung: Extreme Werte für Kante (4731, 976).
# Warnung: Extreme Werte für Kante (4731, 2955).
# Warnung: Extreme Werte für Kante (4731, 5703).
# Warnung: Extreme Werte für Kante (4731, 4734).
# Warnung: Extreme Werte für Kante (4732, 2427).
# Warnung: Extreme Werte für Kante (4732, 1430).
# Warnung: Extreme Werte für Kante (4732, 5948).
# Warnung: Extreme Werte für Kante (4732, 377).
# Warnung: Extreme Werte für Kante (4733, 883).
# Warnung: Extreme Werte für Kante (4733, 3035).
# Warnung: Extreme Werte für Kante (4733, 5920).
# Warnung: Extreme Werte für Kante (4733, 2163).
# Warnung: Extreme Werte für Kante (4733, 1431).
# Warnung: Extreme Werte für Kante (4733, 445).
# Warnung: Extreme Werte für Kante (4733, 847).
# Warnung: Extreme Werte für Kante (4733, 3579).
# Warnung: Extreme Werte für Kante (4733, 3191).
# Warnung: Extreme Werte für Kante (4733, 1296).
# Warnung: Extreme Werte für Kante (4733, 5699).
# Warnung: Extreme Werte für Kante (4733, 1793).
# Warnung: Extreme Werte für Kante (4733, 3081).
# Warnung: Extreme Werte für Kante (4733, 7116).
# Warnung: Extreme Werte für Kante (4733, 1123).
# Warnung: Extreme Werte für Kante (4733, 1167).
# Warnung: Extreme Werte für Kante (4733, 3105).
# Warnung: Extreme Werte für Kante (4733, 922).
# Warnung: Extreme Werte für Kante (4733, 3778).
# Warnung: Extreme Werte für Kante (4733, 3727).
# Warnung: Extreme Werte für Kante (4733, 382).
# Warnung: Extreme Werte für Kante (4733, 956).
# Warnung: Extreme Werte für Kante (4733, 1729).
# Warnung: Extreme Werte für Kante (4733, 940).
# Warnung: Extreme Werte für Kante (4734, 5047).
# Warnung: Extreme Werte für Kante (4734, 8188).
# Warnung: Extreme Werte für Kante (4734, 1218).
# Warnung: Extreme Werte für Kante (4734, 2608).
# Warnung: Extreme Werte für Kante (4734, 4143).
# Warnung: Extreme Werte für Kante (4734, 8212).
# Warnung: Extreme Werte für Kante (4734, 3084).
# Warnung: Extreme Werte für Kante (4734, 1231).
# Warnung: Extreme Werte für Kante (4734, 8211).
# Warnung: Extreme Werte für Kante (4734, 1235).
# Warnung: Extreme Werte für Kante (4735, 4858).
# Warnung: Extreme Werte für Kante (4735, 6324).
# Warnung: Extreme Werte für Kante (4736, 3162).
# Warnung: Extreme Werte für Kante (4736, 5811).
# Warnung: Extreme Werte für Kante (4736, 1783).
# Warnung: Extreme Werte für Kante (4736, 5798).
# Warnung: Extreme Werte für Kante (4736, 5580).
# Warnung: Extreme Werte für Kante (4736, 1194).
# Warnung: Extreme Werte für Kante (4736, 4075).
# Warnung: Extreme Werte für Kante (4736, 7652).
# Warnung: Extreme Werte für Kante (4736, 6712).
# Warnung: Extreme Werte für Kante (4736, 6124).
# Warnung: Extreme Werte für Kante (4736, 5589).
# Warnung: Extreme Werte für Kante (4736, 1349).
# Warnung: Extreme Werte für Kante (4737, 6027).
# Warnung: Extreme Werte für Kante (4737, 901).
# Warnung: Extreme Werte für Kante (4737, 7129).
# Warnung: Extreme Werte für Kante (4737, 8235).
# Warnung: Extreme Werte für Kante (1075, 1388).
# Warnung: Extreme Werte für Kante (1075, 460).
# Warnung: Extreme Werte für Kante (1075, 1392).
# Warnung: Extreme Werte für Kante (1075, 5908).
# Warnung: Extreme Werte für Kante (1075, 5926).
# Warnung: Extreme Werte für Kante (1075, 1412).
# Warnung: Extreme Werte für Kante (1075, 1041).
# Warnung: Extreme Werte für Kante (1075, 1093).
# Warnung: Extreme Werte für Kante (1075, 5913).
# Warnung: Extreme Werte für Kante (1075, 445).
# Warnung: Extreme Werte für Kante (1075, 2029).
# Warnung: Extreme Werte für Kante (1075, 57).
# Warnung: Extreme Werte für Kante (1075, 1368).
# Warnung: Extreme Werte für Kante (1075, 1413).
# Warnung: Extreme Werte für Kante (4940, 1606).
# Warnung: Extreme Werte für Kante (4940, 6344).
# Warnung: Extreme Werte für Kante (4940, 5001).
# Warnung: Extreme Werte für Kante (4940, 2323).
# Warnung: Extreme Werte für Kante (4940, 5500).
# Warnung: Extreme Werte für Kante (4940, 1751).
# Warnung: Extreme Werte für Kante (4940, 6311).
# Warnung: Extreme Werte für Kante (4940, 6281).
# Warnung: Extreme Werte für Kante (4940, 6300).
# Warnung: Extreme Werte für Kante (4940, 4969).
# Warnung: Extreme Werte für Kante (4940, 1597).
# Warnung: Extreme Werte für Kante (4940, 1736).
# Warnung: Extreme Werte für Kante (4940, 4960).
# Warnung: Extreme Werte für Kante (4940, 6253).
# Warnung: Extreme Werte für Kante (4940, 1596).
# Warnung: Extreme Werte für Kante (4940, 6280).
# Warnung: Extreme Werte für Kante (4940, 4982).
# Warnung: Extreme Werte für Kante (4940, 6333).
# Warnung: Extreme Werte für Kante (4940, 377).
# Warnung: Extreme Werte für Kante (4940, 6309).
# Warnung: Extreme Werte für Kante (4940, 7949).
# Warnung: Extreme Werte für Kante (4940, 1592).
# Warnung: Extreme Werte für Kante (4940, 4995).
# Warnung: Extreme Werte für Kante (4940, 6337).
# Warnung: Extreme Werte für Kante (4940, 6314).
# Warnung: Extreme Werte für Kante (4940, 6317).
# Warnung: Extreme Werte für Kante (7818, 4028).
# Warnung: Extreme Werte für Kante (7818, 2208).
# Warnung: Extreme Werte für Kante (7818, 6489).
# Warnung: Extreme Werte für Kante (7818, 4201).
# Warnung: Extreme Werte für Kante (7818, 6483).
# Warnung: Extreme Werte für Kante (7818, 7833).
# Warnung: Extreme Werte für Kante (7818, 6490).
# Warnung: Extreme Werte für Kante (7818, 7816).
# Warnung: Extreme Werte für Kante (7818, 4690).
# Warnung: Extreme Werte für Kante (7818, 5300).
# Warnung: Extreme Werte für Kante (7818, 7817).
# Warnung: Extreme Werte für Kante (7818, 667).
# Warnung: Extreme Werte für Kante (7818, 6494).
# Warnung: Extreme Werte für Kante (7818, 583).
# Warnung: Extreme Werte für Kante (7818, 7866).
# Warnung: Extreme Werte für Kante (7818, 7827).
# Warnung: Extreme Werte für Kante (7818, 7642).
# Warnung: Extreme Werte für Kante (7818, 7809).
# Warnung: Extreme Werte für Kante (7818, 7757).
# Warnung: Extreme Werte für Kante (7818, 4179).
# Warnung: Extreme Werte für Kante (7818, 2509).
# Warnung: Extreme Werte für Kante (7818, 6948).
# Warnung: Extreme Werte für Kante (6307, 4968).
# Warnung: Extreme Werte für Kante (6307, 468).
# Warnung: Extreme Werte für Kante (6307, 6333).
# Warnung: Extreme Werte für Kante (6307, 5482).
# Warnung: Extreme Werte für Kante (6307, 4988).
# Warnung: Extreme Werte für Kante (6307, 6298).
# Warnung: Extreme Werte für Kante (6307, 4982).
# Warnung: Extreme Werte für Kante (6277, 1606).
# Warnung: Extreme Werte für Kante (6277, 1591).
# Warnung: Extreme Werte für Kante (6277, 1592).
# Warnung: Extreme Werte für Kante (6277, 6269).
# Warnung: Extreme Werte für Kante (6277, 1601).
# Warnung: Extreme Werte für Kante (6277, 4995).
# Warnung: Extreme Werte für Kante (6277, 5597).
# Warnung: Extreme Werte für Kante (6277, 7952).
# Warnung: Extreme Werte für Kante (6277, 6296).
# Warnung: Extreme Werte für Kante (6277, 6332).
# Warnung: Extreme Werte für Kante (6277, 1602).
# Warnung: Extreme Werte für Kante (6277, 468).
# Warnung: Extreme Werte für Kante (6277, 5481).
# Warnung: Extreme Werte für Kante (2220, 2198).
# Warnung: Extreme Werte für Kante (2220, 1802).
# Warnung: Extreme Werte für Kante (2220, 1825).
# Warnung: Extreme Werte für Kante (2220, 1731).
# Warnung: Extreme Werte für Kante (2220, 4970).
# Warnung: Extreme Werte für Kante (2220, 1736).
# Warnung: Extreme Werte für Kante (2220, 8192).
# Warnung: Extreme Werte für Kante (2220, 1748).
# Warnung: Extreme Werte für Kante (2220, 4601).
# Warnung: Extreme Werte für Kante (2220, 4981).
# Warnung: Extreme Werte für Kante (2220, 1738).
# Warnung: Extreme Werte für Kante (2220, 1831).
# Warnung: Extreme Werte für Kante (2220, 6275).
# Warnung: Extreme Werte für Kante (2220, 129).
# Warnung: Extreme Werte für Kante (2220, 2323).
# Warnung: Extreme Werte für Kante (2220, 6292).
# Warnung: Extreme Werte für Kante (2220, 5007).
# Warnung: Extreme Werte für Kante (2220, 4961).
# Warnung: Extreme Werte für Kante (2220, 4949).
# Warnung: Extreme Werte für Kante (2220, 1810).
# Warnung: Extreme Werte für Kante (2220, 4952).
# Warnung: Extreme Werte für Kante (2220, 1851).
# Warnung: Extreme Werte für Kante (2220, 4334).
# Warnung: Extreme Werte für Kante (2220, 4991).
# Warnung: Extreme Werte für Kante (2220, 1752).
# Warnung: Extreme Werte für Kante (4944, 6344).
# Warnung: Extreme Werte für Kante (4944, 5012).
# Warnung: Extreme Werte für Kante (4944, 4979).
# Warnung: Extreme Werte für Kante (4944, 4958).
# Warnung: Extreme Werte für Kante (4944, 6290).
# Warnung: Extreme Werte für Kante (4944, 1713).
# Warnung: Extreme Werte für Kante (4944, 4941).
# Warnung: Extreme Werte für Kante (4944, 1674).
# Warnung: Extreme Werte für Kante (4944, 1861).
# Warnung: Extreme Werte für Kante (4944, 4960).
# Warnung: Extreme Werte für Kante (4944, 1738).
# Warnung: Extreme Werte für Kante (4944, 1682).
# Warnung: Extreme Werte für Kante (4944, 4978).
# Warnung: Extreme Werte für Kante (4944, 4991).
# Warnung: Extreme Werte für Kante (4944, 377).
# Warnung: Extreme Werte für Kante (4944, 1516).
# Warnung: Extreme Werte für Kante (4944, 6298).
# Warnung: Extreme Werte für Kante (6263, 468).
# Warnung: Extreme Werte für Kante (6263, 5482).
# Warnung: Extreme Werte für Kante (6263, 6354).
# Warnung: Extreme Werte für Kante (890, 1172).
# Warnung: Extreme Werte für Kante (890, 1893).
# Warnung: Extreme Werte für Kante (890, 1931).
# Warnung: Extreme Werte für Kante (890, 4803).
# Warnung: Extreme Werte für Kante (890, 1528).
# Warnung: Extreme Werte für Kante (890, 724).
# Warnung: Extreme Werte für Kante (890, 1315).
# Warnung: Extreme Werte für Kante (890, 77).
# Warnung: Extreme Werte für Kante (890, 1658).
# Warnung: Extreme Werte für Kante (890, 3825).
# Warnung: Extreme Werte für Kante (890, 48).
# Warnung: Extreme Werte für Kante (890, 1732).
# Warnung: Extreme Werte für Kante (890, 4753).
# Warnung: Extreme Werte für Kante (890, 1440).
# Warnung: Extreme Werte für Kante (890, 440).
# Warnung: Extreme Werte für Kante (890, 1930).
# Warnung: Extreme Werte für Kante (890, 2604).
# Warnung: Extreme Werte für Kante (890, 2232).
# Warnung: Extreme Werte für Kante (890, 2888).
# Warnung: Extreme Werte für Kante (890, 1153).
# Warnung: Extreme Werte für Kante (890, 3743).
# Warnung: Extreme Werte für Kante (890, 4037).
# Warnung: Extreme Werte für Kante (890, 2868).
# Warnung: Extreme Werte für Kante (890, 465).
# Warnung: Extreme Werte für Kante (890, 2453).
# Warnung: Extreme Werte für Kante (890, 1554).
# Warnung: Extreme Werte für Kante (890, 281).
# Warnung: Extreme Werte für Kante (890, 4042).
# Warnung: Extreme Werte für Kante (890, 869).
# Warnung: Extreme Werte für Kante (890, 3710).
# Warnung: Extreme Werte für Kante (890, 369).
# Warnung: Extreme Werte für Kante (890, 186).
# Warnung: Extreme Werte für Kante (890, 375).
# Warnung: Extreme Werte für Kante (890, 2902).
# Warnung: Extreme Werte für Kante (890, 3274).
# Warnung: Extreme Werte für Kante (4955, 1708).
# Warnung: Extreme Werte für Kante (4955, 1839).
# Warnung: Extreme Werte für Kante (4955, 4979).
# Warnung: Extreme Werte für Kante (4955, 6325).
# Warnung: Extreme Werte für Kante (4955, 6275).
# Warnung: Extreme Werte für Kante (4955, 1123).
# Warnung: Extreme Werte für Kante (4955, 4977).
# Warnung: Extreme Werte für Kante (4955, 4978).
# Warnung: Extreme Werte für Kante (4955, 1736).
# Warnung: Extreme Werte für Kante (4955, 7536).
# Warnung: Extreme Werte für Kante (4955, 1819).
# Warnung: Extreme Werte für Kante (4955, 1794).
# Warnung: Extreme Werte für Kante (4955, 4981).
# Warnung: Extreme Werte für Kante (4955, 7950).
# Warnung: Extreme Werte für Kante (4955, 4997).
# Warnung: Extreme Werte für Kante (4955, 4853).
# Warnung: Extreme Werte für Kante (4955, 3678).
# Warnung: Extreme Werte für Kante (4955, 377).
# Warnung: Extreme Werte für Kante (3524, 1225).
# Warnung: Extreme Werte für Kante (3524, 5631).
# Warnung: Extreme Werte für Kante (3524, 1205).
# Warnung: Extreme Werte für Kante (3524, 862).
# Warnung: Extreme Werte für Kante (3524, 2004).
# Warnung: Extreme Werte für Kante (3524, 934).
# Warnung: Extreme Werte für Kante (3524, 5255).
# Warnung: Extreme Werte für Kante (3524, 1576).
# Warnung: Extreme Werte für Kante (3524, 7371).
# Warnung: Extreme Werte für Kante (3524, 5050).
# Warnung: Extreme Werte für Kante (3524, 986).
# Warnung: Extreme Werte für Kante (3524, 260).
# Warnung: Extreme Werte für Kante (3524, 1216).
# Warnung: Extreme Werte für Kante (3524, 3857).
# Warnung: Extreme Werte für Kante (3524, 1217).
# Warnung: Extreme Werte für Kante (3524, 1222).
# Warnung: Extreme Werte für Kante (3524, 3526).
# Warnung: Extreme Werte für Kante (3524, 4909).
# Warnung: Extreme Werte für Kante (3524, 1252).
# Warnung: Extreme Werte für Kante (3524, 6379).
# Warnung: Extreme Werte für Kante (3524, 4752).
# Warnung: Extreme Werte für Kante (3524, 1229).
# Warnung: Extreme Werte für Kante (3524, 1930).
# Warnung: Extreme Werte für Kante (4961, 3292).
# Warnung: Extreme Werte für Kante (4961, 5012).
# Warnung: Extreme Werte für Kante (4961, 5001).
# Warnung: Extreme Werte für Kante (4961, 5008).
# Warnung: Extreme Werte für Kante (4961, 4992).
# Warnung: Extreme Werte für Kante (4961, 6282).
# Warnung: Extreme Werte für Kante (4961, 1751).
# Warnung: Extreme Werte für Kante (4961, 2844).
# Warnung: Extreme Werte für Kante (4961, 1976).
# Warnung: Extreme Werte für Kante (4961, 7853).
# Warnung: Extreme Werte für Kante (4961, 2035).
# Warnung: Extreme Werte für Kante (4961, 4034).
# Warnung: Extreme Werte für Kante (4961, 4950).
# Warnung: Extreme Werte für Kante (4961, 4954).
# Warnung: Extreme Werte für Kante (4961, 1682).
# Warnung: Extreme Werte für Kante (4961, 4958).
# Warnung: Extreme Werte für Kante (4961, 3876).
# Warnung: Extreme Werte für Kante (4961, 1951).
# Warnung: Extreme Werte für Kante (4961, 377).
# Warnung: Extreme Werte für Kante (4961, 4998).
# Warnung: Extreme Werte für Kante (4961, 6333).
# Warnung: Extreme Werte für Kante (4961, 1825).
# Warnung: Extreme Werte für Kante (4961, 1851).
# Warnung: Extreme Werte für Kante (4961, 1416).
# Warnung: Extreme Werte für Kante (4968, 5001).
# Warnung: Extreme Werte für Kante (4968, 1684).
# Warnung: Extreme Werte für Kante (4968, 1602).
# Warnung: Extreme Werte für Kante (4968, 4977).
# Warnung: Extreme Werte für Kante (4968, 1031).
# Warnung: Extreme Werte für Kante (4968, 4946).
# Warnung: Extreme Werte für Kante (4968, 4975).
# Warnung: Extreme Werte für Kante (4968, 6253).
# Warnung: Extreme Werte für Kante (4968, 1801).
# Warnung: Extreme Werte für Kante (4968, 1592).
# Warnung: Extreme Werte für Kante (4968, 4034).
# Warnung: Extreme Werte für Kante (4968, 4952).
# Warnung: Extreme Werte für Kante (4968, 4982).
# Warnung: Extreme Werte für Kante (4968, 7949).
# Warnung: Extreme Werte für Kante (4968, 4988).
# Warnung: Extreme Werte für Kante (4968, 1615).
# Warnung: Extreme Werte für Kante (4968, 377).
# Warnung: Extreme Werte für Kante (4979, 1839).
# Warnung: Extreme Werte für Kante (4979, 5012).
# Warnung: Extreme Werte für Kante (4979, 4992).
# Warnung: Extreme Werte für Kante (4979, 4946).
# Warnung: Extreme Werte für Kante (4979, 4034).
# Warnung: Extreme Werte für Kante (4979, 4950).
# Warnung: Extreme Werte für Kante (4979, 4958).
# Warnung: Extreme Werte für Kante (4979, 4978).
# Warnung: Extreme Werte für Kante (4979, 4982).
# Warnung: Extreme Werte für Kante (4979, 1831).
# Warnung: Extreme Werte für Kante (4979, 1751).
# Warnung: Extreme Werte für Kante (4979, 3751).
# Warnung: Extreme Werte für Kante (4979, 377).
# Warnung: Extreme Werte für Kante (4979, 2844).
# Warnung: Extreme Werte für Kante (6286, 6672).
# Warnung: Extreme Werte für Kante (6286, 1731).
# Warnung: Extreme Werte für Kante (6286, 4334).
# Warnung: Extreme Werte für Kante (6286, 468).
# Warnung: Extreme Werte für Kante (6286, 4184).
# Warnung: Extreme Werte für Kante (6286, 1689).
# Warnung: Extreme Werte für Kante (6286, 4991).
# Warnung: Extreme Werte für Kante (6286, 4170).
# Warnung: Extreme Werte für Kante (6286, 6342).
# Warnung: Extreme Werte für Kante (6286, 6328).
# Warnung: Extreme Werte für Kante (6286, 2981).
# Warnung: Extreme Werte für Kante (377, 4953).
# Warnung: Extreme Werte für Kante (377, 5006).
# Warnung: Extreme Werte für Kante (377, 4996).
# Warnung: Extreme Werte für Kante (377, 4985).
# Warnung: Extreme Werte für Kante (377, 3736).
# Warnung: Extreme Werte für Kante (377, 5012).
# Warnung: Extreme Werte für Kante (377, 4980).
# Warnung: Extreme Werte für Kante (377, 5001).
# Warnung: Extreme Werte für Kante (377, 5008).
# Warnung: Extreme Werte für Kante (377, 5011).
# Warnung: Extreme Werte für Kante (377, 4939).
# Warnung: Extreme Werte für Kante (377, 1315).
# Warnung: Extreme Werte für Kante (377, 4974).
# Warnung: Extreme Werte für Kante (377, 4966).
# Warnung: Extreme Werte für Kante (377, 5013).
# Warnung: Extreme Werte für Kante (377, 2580).
# Warnung: Extreme Werte für Kante (377, 5003).
# Warnung: Extreme Werte für Kante (377, 4963).
# Warnung: Extreme Werte für Kante (377, 2338).
# Warnung: Extreme Werte für Kante (377, 5015).
# Warnung: Extreme Werte für Kante (377, 4992).
# Warnung: Extreme Werte für Kante (377, 4958).
# Warnung: Extreme Werte für Kante (377, 4950).
# Warnung: Extreme Werte für Kante (377, 2607).
# Warnung: Extreme Werte für Kante (377, 4965).
# Warnung: Extreme Werte für Kante (377, 4964).
# Warnung: Extreme Werte für Kante (377, 5016).
# Warnung: Extreme Werte für Kante (377, 4943).
# Warnung: Extreme Werte für Kante (377, 4967).
# Warnung: Extreme Werte für Kante (377, 4990).
# Warnung: Extreme Werte für Kante (377, 4977).
# Warnung: Extreme Werte für Kante (377, 2508).
# Warnung: Extreme Werte für Kante (377, 4954).
# Warnung: Extreme Werte für Kante (377, 4983).
# Warnung: Extreme Werte für Kante (377, 4987).
# Warnung: Extreme Werte für Kante (377, 4941).
# Warnung: Extreme Werte für Kante (377, 4949).
# Warnung: Extreme Werte für Kante (377, 1674).
# Warnung: Extreme Werte für Kante (377, 4969).
# Warnung: Extreme Werte für Kante (377, 4962).
# Warnung: Extreme Werte für Kante (377, 4970).
# Warnung: Extreme Werte für Kante (377, 1597).
# Warnung: Extreme Werte für Kante (377, 4999).
# Warnung: Extreme Werte für Kante (377, 4946).
# Warnung: Extreme Werte für Kante (377, 5014).
# Warnung: Extreme Werte für Kante (377, 5004).
# Warnung: Extreme Werte für Kante (377, 4754).
# Warnung: Extreme Werte für Kante (377, 4997).
# Warnung: Extreme Werte für Kante (377, 4960).
# Warnung: Extreme Werte für Kante (377, 1810).
# Warnung: Extreme Werte für Kante (377, 4975).
# Warnung: Extreme Werte für Kante (377, 4957).
# Warnung: Extreme Werte für Kante (377, 4972).
# Warnung: Extreme Werte für Kante (377, 5002).
# Warnung: Extreme Werte für Kante (377, 1737).
# Warnung: Extreme Werte für Kante (377, 4978).
# Warnung: Extreme Werte für Kante (377, 4976).
# Warnung: Extreme Werte für Kante (377, 5005).
# Warnung: Extreme Werte für Kante (377, 4982).
# Warnung: Extreme Werte für Kante (377, 4952).
# Warnung: Extreme Werte für Kante (377, 4989).
# Warnung: Extreme Werte für Kante (377, 4981).
# Warnung: Extreme Werte für Kante (377, 5007).
# Warnung: Extreme Werte für Kante (377, 4991).
# Warnung: Extreme Werte für Kante (377, 4942).
# Warnung: Extreme Werte für Kante (377, 4945).
# Warnung: Extreme Werte für Kante (377, 4034).
# Warnung: Extreme Werte für Kante (377, 4947).
# Warnung: Extreme Werte für Kante (377, 4948).
# Warnung: Extreme Werte für Kante (377, 4951).
# Warnung: Extreme Werte für Kante (377, 4956).
# Warnung: Extreme Werte für Kante (377, 4959).
# Warnung: Extreme Werte für Kante (377, 4971).
# Warnung: Extreme Werte für Kante (377, 4973).
# Warnung: Extreme Werte für Kante (377, 4984).
# Warnung: Extreme Werte für Kante (377, 4986).
# Warnung: Extreme Werte für Kante (377, 4988).
# Warnung: Extreme Werte für Kante (377, 4993).
# Warnung: Extreme Werte für Kante (377, 4994).
# Warnung: Extreme Werte für Kante (377, 4995).
# Warnung: Extreme Werte für Kante (377, 4998).
# Warnung: Extreme Werte für Kante (377, 5000).
# Warnung: Extreme Werte für Kante (377, 5009).
# Warnung: Extreme Werte für Kante (377, 5010).
# Warnung: Extreme Werte für Kante (1783, 4803).
# Warnung: Extreme Werte für Kante (1783, 7421).
# Warnung: Extreme Werte für Kante (1783, 6344).
# Warnung: Extreme Werte für Kante (1783, 3808).
# Warnung: Extreme Werte für Kante (1783, 1512).
# Warnung: Extreme Werte für Kante (1783, 3495).
# Warnung: Extreme Werte für Kante (1783, 1399).
# Warnung: Extreme Werte für Kante (1783, 980).
# Warnung: Extreme Werte für Kante (1783, 6005).
# Warnung: Extreme Werte für Kante (1783, 1394).
# Warnung: Extreme Werte für Kante (1783, 1939).
# Warnung: Extreme Werte für Kante (1783, 962).
# Warnung: Extreme Werte für Kante (1783, 3341).
# Warnung: Extreme Werte für Kante (1783, 4071).
# Warnung: Extreme Werte für Kante (1783, 2178).
# Warnung: Extreme Werte für Kante (1783, 1776).
# Warnung: Extreme Werte für Kante (1783, 3869).
# Warnung: Extreme Werte für Kante (1783, 108).
# Warnung: Extreme Werte für Kante (1783, 1810).
# Warnung: Extreme Werte für Kante (1783, 6267).
# Warnung: Extreme Werte für Kante (1783, 4957).
# Warnung: Extreme Werte für Kante (1783, 1777).
# Warnung: Extreme Werte für Kante (1783, 1738).
# Warnung: Extreme Werte für Kante (1783, 4978).
# Warnung: Extreme Werte für Kante (1783, 4981).
# Warnung: Extreme Werte für Kante (1783, 6620).
# Warnung: Extreme Werte für Kante (4991, 6344).
# Warnung: Extreme Werte für Kante (4991, 5013).
# Warnung: Extreme Werte für Kante (4991, 4649).
# Warnung: Extreme Werte für Kante (4991, 6129).
# Warnung: Extreme Werte für Kante (4991, 1835).
# Warnung: Extreme Werte für Kante (4991, 1674).
# Warnung: Extreme Werte für Kante (4991, 3739).
# Warnung: Extreme Werte für Kante (4991, 1738).
# Warnung: Extreme Werte für Kante (4991, 1810).
# Warnung: Extreme Werte für Kante (4991, 1689).
# Warnung: Extreme Werte für Kante (4991, 5007).
# Warnung: Extreme Werte für Kante (4991, 4971).
# Warnung: Extreme Werte für Kante (4991, 4993).
# Warnung: Extreme Werte für Kante (6336, 1414).
# Warnung: Extreme Werte für Kante (6336, 1839).
# Warnung: Extreme Werte für Kante (6336, 1764).
# Warnung: Extreme Werte für Kante (6336, 2159).
# Warnung: Extreme Werte für Kante (6336, 2492).
# Warnung: Extreme Werte für Kante (6336, 5013).
# Warnung: Extreme Werte für Kante (6336, 6386).
# Warnung: Extreme Werte für Kante (6336, 6282).
# Warnung: Extreme Werte für Kante (6336, 4965).
# Warnung: Extreme Werte für Kante (6336, 1748).
# Warnung: Extreme Werte für Kante (6336, 7371).
# Warnung: Extreme Werte für Kante (6336, 4860).
# Warnung: Extreme Werte für Kante (6336, 4376).
# Warnung: Extreme Werte für Kante (6336, 1682).
# Warnung: Extreme Werte für Kante (6336, 4960).
# Warnung: Extreme Werte für Kante (6336, 3499).
# Warnung: Extreme Werte für Kante (6336, 3504).
# Warnung: Extreme Werte für Kante (6336, 1701).
# Warnung: Extreme Werte für Kante (6336, 1864).
# Warnung: Extreme Werte für Kante (6336, 468).
# Warnung: Extreme Werte für Kante (6336, 3678).
# Warnung: Extreme Werte für Kante (6336, 2246).
# Warnung: Extreme Werte für Kante (6336, 3813).
# Warnung: Extreme Werte für Kante (6336, 1371).
# Warnung: Extreme Werte für Kante (6336, 1794).
# Warnung: Extreme Werte für Kante (6336, 4853).
# Warnung: Extreme Werte für Kante (6336, 2267).
# Warnung: Extreme Werte für Kante (4982, 5012).
# Warnung: Extreme Werte für Kante (4982, 5016).
# Warnung: Extreme Werte für Kante (4982, 1825).
# Warnung: Extreme Werte für Kante (4982, 4941).
# Warnung: Extreme Werte für Kante (4982, 4978).
# Warnung: Extreme Werte für Kante (4982, 4034).
# Warnung: Extreme Werte für Kante (4982, 4952).
# Warnung: Extreme Werte für Kante (4982, 4971).
# Warnung: Extreme Werte für Kante (1851, 1816).
# Warnung: Extreme Werte für Kante (1851, 2670).
# Warnung: Extreme Werte für Kante (1851, 1197).
# Warnung: Extreme Werte für Kante (1851, 1684).
# Warnung: Extreme Werte für Kante (1851, 1731).
# Warnung: Extreme Werte für Kante (1851, 4950).
# Warnung: Extreme Werte für Kante (1851, 108).
# Warnung: Extreme Werte für Kante (1851, 3445).
# Warnung: Extreme Werte für Kante (1851, 4949).
# Warnung: Extreme Werte für Kante (1851, 2198).
# Warnung: Extreme Werte für Kante (1851, 1728).
# Warnung: Extreme Werte für Kante (1851, 6699).
# Warnung: Extreme Werte für Kante (1851, 4970).
# Warnung: Extreme Werte für Kante (1851, 4334).
# Warnung: Extreme Werte für Kante (1851, 1748).
# Warnung: Extreme Werte für Kante (1851, 1613).
# Warnung: Extreme Werte für Kante (1851, 1831).
# Warnung: Extreme Werte für Kante (5001, 6344).
# Warnung: Extreme Werte für Kante (5001, 1801).
# Warnung: Extreme Werte für Kante (5001, 4941).
# Warnung: Extreme Werte für Kante (5001, 4034).
# Warnung: Extreme Werte für Kante (5001, 4950).
# Warnung: Extreme Werte für Kante (5001, 4969).
# Warnung: Extreme Werte für Kante (5001, 6333).
# Warnung: Extreme Werte für Kante (5001, 7949).
# Warnung: Extreme Werte für Kante (5001, 1674).
# Warnung: Extreme Werte für Kante (5001, 5008).
# Warnung: Extreme Werte für Kante (5001, 6325).
# Warnung: Extreme Werte für Kante (5001, 6341).
# Warnung: Extreme Werte für Kante (5001, 4988).
# Warnung: Extreme Werte für Kante (5001, 6317).
# Warnung: Extreme Werte für Kante (5001, 5007).
# Warnung: Extreme Werte für Kante (1337, 5775).
# Warnung: Extreme Werte für Kante (1337, 2862).
# Warnung: Extreme Werte für Kante (1337, 1612).
# Warnung: Extreme Werte für Kante (1337, 5175).
# Warnung: Extreme Werte für Kante (1337, 1484).
# Warnung: Extreme Werte für Kante (1337, 4606).
# Warnung: Extreme Werte für Kante (1337, 4104).
# Warnung: Extreme Werte für Kante (1337, 5337).
# Warnung: Extreme Werte für Kante (1337, 3999).
# Warnung: Extreme Werte für Kante (1337, 7110).
# Warnung: Extreme Werte für Kante (1337, 5609).
# Warnung: Extreme Werte für Kante (1337, 5217).
# Warnung: Extreme Werte für Kante (1337, 3171).
# Warnung: Extreme Werte für Kante (1337, 5094).
# Warnung: Extreme Werte für Kante (1337, 3202).
# /var/folders/sj/tgql6qpd47j0ffyrwhssd1tw0000gp/T/ipykernel_36924/4180327057.py:42: RuntimeWarning: overflow encountered in scalar multiply
#   risk_weights["none"] * neither_genres
# Warnung: Extreme Werte für Kante (1337, 2930).
# Warnung: Extreme Werte für Kante (1337, 1447).
# Warnung: Extreme Werte für Kante (1337, 694).
# Warnung: Extreme Werte für Kante (1337, 7263).
# Warnung: Extreme Werte für Kante (1337, 3210).
# Warnung: Extreme Werte für Kante (1337, 6512).
# Warnung: Extreme Werte für Kante (1337, 5380).
# Warnung: Extreme Werte für Kante (1337, 6957).
# Warnung: Extreme Werte für Kante (1337, 1437).
# Warnung: Extreme Werte für Kante (1337, 5338).
# Warnung: Extreme Werte für Kante (1337, 4475).
# Warnung: Extreme Werte für Kante (1337, 1499).
# Warnung: Extreme Werte für Kante (1337, 7139).
# Warnung: Extreme Werte für Kante (1337, 7784).
# Warnung: Extreme Werte für Kante (1337, 5655).
# Warnung: Extreme Werte für Kante (1337, 5700).
# Warnung: Extreme Werte für Kante (1337, 1493).
# Warnung: Extreme Werte für Kante (1337, 79).
# Warnung: Extreme Werte für Kante (1337, 4847).
# Warnung: Extreme Werte für Kante (1337, 5642).
# Warnung: Extreme Werte für Kante (1337, 1429).
# Warnung: Extreme Werte für Kante (1337, 5349).
# Warnung: Extreme Werte für Kante (1337, 5348).
# Warnung: Extreme Werte für Kante (1337, 5457).
# Warnung: Extreme Werte für Kante (1337, 1314).
# Warnung: Extreme Werte für Kante (1337, 1348).
# Warnung: Extreme Werte für Kante (1337, 4119).
# Warnung: Extreme Werte für Kante (1337, 1316).
# Warnung: Extreme Werte für Kante (429, 5775).
# Warnung: Extreme Werte für Kante (429, 5772).
# Warnung: Extreme Werte für Kante (429, 5569).
# Warnung: Extreme Werte für Kante (429, 5781).
# Warnung: Extreme Werte für Kante (429, 1533).
# Warnung: Extreme Werte für Kante (429, 5783).
# Warnung: Extreme Werte für Kante (429, 5771).
# Warnung: Extreme Werte für Kante (429, 5773).
# Warnung: Extreme Werte für Kante (429, 5776).
# Warnung: Extreme Werte für Kante (429, 17).
# Warnung: Extreme Werte für Kante (429, 5767).
# Warnung: Extreme Werte für Kante (429, 5766).
# Warnung: Extreme Werte für Kante (429, 417).
# Warnung: Extreme Werte für Kante (429, 5769).
# Warnung: Extreme Werte für Kante (429, 5777).
# Warnung: Extreme Werte für Kante (429, 5768).
# Warnung: Extreme Werte für Kante (429, 5608).
# Warnung: Extreme Werte für Kante (429, 5770).
# Warnung: Extreme Werte für Kante (429, 5774).
# Warnung: Extreme Werte für Kante (429, 425).
# Warnung: Extreme Werte für Kante (429, 5778).
# Warnung: Extreme Werte für Kante (429, 5779).
# Warnung: Extreme Werte für Kante (429, 5780).
# Warnung: Extreme Werte für Kante (429, 5782).
# Warnung: Extreme Werte für Kante (5782, 5105).
# Warnung: Extreme Werte für Kante (5782, 1493).
# Warnung: Extreme Werte für Kante (5782, 7126).
# Warnung: Extreme Werte für Kante (5782, 4161).
# Warnung: Extreme Werte für Kante (5782, 4105).
# Warnung: Extreme Werte für Kante (5782, 534).
# Warnung: Extreme Werte für Kante (5782, 1133).
# Warnung: Extreme Werte für Kante (5782, 697).
# Warnung: Extreme Werte für Kante (5782, 7963).
# Warnung: Extreme Werte für Kante (7424, 6800).
# Warnung: Extreme Werte für Kante (7424, 7440).
# Warnung: Extreme Werte für Kante (7424, 2602).
# Warnung: Extreme Werte für Kante (7424, 3559).
# Warnung: Extreme Werte für Kante (7424, 3250).
# Warnung: Extreme Werte für Kante (7424, 2871).
# Warnung: Extreme Werte für Kante (7424, 554).
# Warnung: Extreme Werte für Kante (7424, 7331).
# Warnung: Extreme Werte für Kante (7424, 7948).
# Warnung: Extreme Werte für Kante (7424, 7479).
# Warnung: Extreme Werte für Kante (7424, 4101).
# Warnung: Extreme Werte für Kante (7424, 6605).
# Warnung: Extreme Werte für Kante (7424, 5044).
# Warnung: Extreme Werte für Kante (7424, 8019).
# Warnung: Extreme Werte für Kante (7424, 7327).
# Warnung: Extreme Werte für Kante (7424, 2215).
# Warnung: Extreme Werte für Kante (7424, 2135).
# Warnung: Extreme Werte für Kante (7424, 4063).
# Warnung: Extreme Werte für Kante (7424, 7223).
# Warnung: Extreme Werte für Kante (4908, 1708).
# Warnung: Extreme Werte für Kante (4908, 5024).
# Warnung: Extreme Werte für Kante (4908, 2954).
# Warnung: Extreme Werte für Kante (4908, 1794).
# Warnung: Extreme Werte für Kante (4908, 375).
# Warnung: Extreme Werte für Kante (4908, 5948).
# Warnung: Extreme Werte für Kante (4908, 2559).
# Warnung: Extreme Werte für Kante (1794, 1708).
# Warnung: Extreme Werte für Kante (1794, 1764).
# Warnung: Extreme Werte für Kante (1794, 6282).
# Warnung: Extreme Werte für Kante (1794, 4977).
# Warnung: Extreme Werte für Kante (1794, 1862).
# Warnung: Extreme Werte für Kante (1794, 108).
# Warnung: Extreme Werte für Kante (1794, 4972).
# Warnung: Extreme Werte für Kante (1794, 1728).
# Warnung: Extreme Werte für Kante (1794, 2305).
# Warnung: Extreme Werte für Kante (1794, 1787).
# Warnung: Extreme Werte für Kante (1794, 6623).
# Warnung: Extreme Werte für Kante (1794, 2302).
# Warnung: Extreme Werte für Kante (1794, 7198).
# Warnung: Extreme Werte für Kante (1794, 5943).
# Warnung: Extreme Werte für Kante (1794, 133).
# Warnung: Extreme Werte für Kante (1794, 3974).
# Warnung: Extreme Werte für Kante (1794, 943).
# Warnung: Extreme Werte für Kante (4101, 4524).
# Warnung: Extreme Werte für Kante (4101, 4549).
# Warnung: Extreme Werte für Kante (4101, 6800).
# Warnung: Extreme Werte für Kante (4101, 7948).
# Warnung: Extreme Werte für Kante (4101, 1551).
# Warnung: Extreme Werte für Kante (4101, 3374).
# Warnung: Extreme Werte für Kante (4101, 319).
# Warnung: Extreme Werte für Kante (4101, 422).
# Warnung: Extreme Werte für Kante (4101, 4411).
# Warnung: Extreme Werte für Kante (4101, 2268).
# Warnung: Extreme Werte für Kante (243, 3333).
# Warnung: Extreme Werte für Kante (243, 3339).
# Warnung: Extreme Werte für Kante (243, 3338).
# Warnung: Extreme Werte für Kante (243, 3331).
# Warnung: Extreme Werte für Kante (243, 1881).
# Warnung: Extreme Werte für Kante (243, 2155).
# Warnung: Extreme Werte für Kante (243, 3345).
# Warnung: Extreme Werte für Kante (243, 156).
# Warnung: Extreme Werte für Kante (243, 492).
# Warnung: Extreme Werte für Kante (243, 279).
# Warnung: Extreme Werte für Kante (243, 9).
# Warnung: Extreme Werte für Kante (243, 305).
# Warnung: Extreme Werte für Kante (243, 452).
# Warnung: Extreme Werte für Kante (243, 299).
# Warnung: Extreme Werte für Kante (243, 1548).
# Warnung: Extreme Werte für Kante (243, 733).
# Warnung: Extreme Werte für Kante (243, 293).
# Warnung: Extreme Werte für Kante (243, 265).
# Warnung: Extreme Werte für Kante (243, 290).
# Warnung: Extreme Werte für Kante (243, 1394).
# Warnung: Extreme Werte für Kante (243, 1939).
# Warnung: Extreme Werte für Kante (243, 191).
# Warnung: Extreme Werte für Kante (243, 280).
# Warnung: Extreme Werte für Kante (243, 303).
# Warnung: Extreme Werte für Kante (243, 444).
# Warnung: Extreme Werte für Kante (243, 446).
# Warnung: Extreme Werte für Kante (243, 2855).
# Warnung: Extreme Werte für Kante (243, 1922).
# Warnung: Extreme Werte für Kante (243, 2989).
# Warnung: Extreme Werte für Kante (243, 3332).
# Warnung: Extreme Werte für Kante (243, 497).
# Warnung: Extreme Werte für Kante (243, 112).
# Warnung: Extreme Werte für Kante (243, 114).
# Warnung: Extreme Werte für Kante (243, 690).
# Warnung: Extreme Werte für Kante (243, 3334).
# Warnung: Extreme Werte für Kante (243, 3335).
# Warnung: Extreme Werte für Kante (243, 3336).
# Warnung: Extreme Werte für Kante (243, 255).
# Warnung: Extreme Werte für Kante (243, 3337).
# Warnung: Extreme Werte für Kante (243, 2331).
# Warnung: Extreme Werte für Kante (243, 3340).
# Warnung: Extreme Werte für Kante (243, 1358).
# Warnung: Extreme Werte für Kante (243, 3341).
# Warnung: Extreme Werte für Kante (243, 3342).
# Warnung: Extreme Werte für Kante (243, 297).
# Warnung: Extreme Werte für Kante (243, 1303).
# Warnung: Extreme Werte für Kante (243, 3343).
# Warnung: Extreme Werte für Kante (243, 1937).
# Warnung: Extreme Werte für Kante (243, 3344).
# Warnung: Extreme Werte für Kante (243, 3346).
# Warnung: Extreme Werte für Kante (243, 298).
# Warnung: Extreme Werte für Kante (243, 3347).
# Warnung: Extreme Werte für Kante (1, 40).
# Warnung: Extreme Werte für Kante (1, 29).
# Warnung: Extreme Werte für Kante (1, 38).
# Warnung: Extreme Werte für Kante (1, 11).
# Warnung: Extreme Werte für Kante (1, 39).
# Warnung: Extreme Werte für Kante (1, 28).
# Warnung: Extreme Werte für Kante (1, 32).
# Warnung: Extreme Werte für Kante (1, 33).
# Warnung: Extreme Werte für Kante (1, 37).
# ...
# Warnung: Extreme Werte für Kante (5304, 6427).
# Warnung: Extreme Werte für Kante (3028, 208).
# Warnung: Extreme Werte für Kante (7945, 7939).
# Warnung: Extreme Werte für Kante (7945, 7943).
# Warnung: Extreme Werte für Kante (3087, 3079).
# Warnung: Extreme Werte für Kante (7567, 7910).
# Warnung: Extreme Werte für Kante (7567, 5671).
# Warnung: Extreme Werte für Kante (5363, 5369).
# Warnung: Extreme Werte für Kante (5363, 1660).
# Warnung: Extreme Werte für Kante (4498, 5838).
# Warnung: Extreme Werte für Kante (4498, 4483).
# Warnung: Extreme Werte für Kante (4498, 5845).
# Warnung: Extreme Werte für Kante (5476, 431).
# Warnung: Extreme Werte für Kante (5476, 3026).
# Warnung: Extreme Werte für Kante (7222, 4684).
# Warnung: Extreme Werte für Kante (7222, 7078).
# Warnung: Extreme Werte für Kante (2303, 1276).
# Warnung: Extreme Werte für Kante (2303, 1465).
# Warnung: Extreme Werte für Kante (793, 4716).
# Warnung: Extreme Werte für Kante (2127, 2121).
# Warnung: Extreme Werte für Kante (7838, 1973).
# Warnung: Extreme Werte für Kante (4109, 7068).
# Warnung: Extreme Werte für Kante (5817, 431).
# Warnung: Extreme Werte für Kante (7113, 7117).
# Warnung: Extreme Werte für Kante (7117, 5712).
# Warnung: Extreme Werte für Kante (6134, 459).
# Warnung: Extreme Werte für Kante (6134, 6135).
# Warnung: Extreme Werte für Kante (208, 3016).
# Warnung: Extreme Werte für Kante (208, 3020).
# Warnung: Extreme Werte für Kante (208, 3025).
# Warnung: Extreme Werte für Kante (208, 3026).
# Warnung: Extreme Werte für Kante (5358, 6196).
# Warnung: Extreme Werte für Kante (4667, 8258).
# Warnung: Extreme Werte für Kante (7069, 7070).
# Warnung: Extreme Werte für Kante (7070, 7068).
# Warnung: Extreme Werte für Kante (1607, 7080).
# Warnung: Extreme Werte für Kante (6835, 6858).
# Warnung: Extreme Werte für Kante (5397, 6849).
# Warnung: Extreme Werte für Kante (3120, 3119).
# Warnung: Extreme Werte für Kante (7224, 3159).
# Warnung: Extreme Werte für Kante (431, 5813).
# Warnung: Extreme Werte für Kante (431, 5815).
# Warnung: Extreme Werte für Kante (431, 5819).
# Warnung: Extreme Werte für Kante (431, 5820).
# Warnung: Extreme Werte für Kante (459, 6133).
# Warnung: Extreme Werte für Kante (459, 6132).
# Warnung: Extreme Werte für Kante (459, 6135).
# Warnung: Extreme Werte für Kante (5365, 5376).
# Warnung: Extreme Werte für Kante (5376, 4126).
# Warnung: Extreme Werte für Kante (6430, 473).
# Warnung: Extreme Werte für Kante (7080, 4424).
# Warnung: Extreme Werte für Kante (3156, 5710).
# Warnung: Extreme Werte für Kante (204, 2994).
# Warnung: Extreme Werte für Kante (3147, 3149).
# Warnung: Extreme Werte für Kante (3149, 3063).
# Warnung: Extreme Werte für Kante (3151, 3153).
# Warnung: Extreme Werte für Kante (6849, 6858).
# Warnung: Extreme Werte für Kante (2392, 2404).
# Warnung: Extreme Werte für Kante (2121, 5951).
# Warnung: Extreme Werte für Kante (1466, 2906).
# Warnung: Extreme Werte für Kante (3160, 3159).
# Warnung: Extreme Werte für Kante (3160, 222).
# Warnung: Extreme Werte für Kante (3159, 5101).
# Warnung: Extreme Werte für Kante (3159, 222).
# Warnung: Extreme Werte für Kante (6684, 6691).
# Warnung: Extreme Werte für Kante (6690, 6691).
# Warnung: Extreme Werte für Kante (147, 2522).
# Warnung: Extreme Werte für Kante (4133, 5773).
# Warnung: Extreme Werte für Kante (8154, 8166).
# Warnung: Extreme Werte für Kante (8158, 8166).
# Warnung: Extreme Werte für Kante (3079, 3055).
# Warnung: Extreme Werte für Kante (5771, 5773).
# Warnung: Extreme Werte für Kante (5771, 3053).
# Warnung: Extreme Werte für Kante (1912, 113).
# Warnung: Extreme Werte für Kante (1912, 1919).
# Warnung: Extreme Werte für Kante (1912, 1915).
# Warnung: Extreme Werte für Kante (1912, 1913).
# Warnung: Extreme Werte für Kante (113, 1913).
# Warnung: Extreme Werte für Kante (113, 1915).
# Warnung: Extreme Werte für Kante (113, 1919).
# Warnung: Extreme Werte für Kante (1961, 6446).
# Warnung: Extreme Werte für Kante (1961, 1972).
# Warnung: Extreme Werte für Kante (6479, 477).
# Warnung: Extreme Werte für Kante (7938, 6197).
# Warnung: Extreme Werte für Kante (1569, 611).
# Warnung: Extreme Werte für Kante (1915, 1919).
# Warnung: Extreme Werte für Kante (2994, 8245).
# Warnung: Extreme Werte für Kante (5964, 4148).
# Warnung: Extreme Werte für Kante (6190, 7584).
# Warnung: Extreme Werte für Kante (6190, 6195).
# Warnung: Extreme Werte für Kante (5706, 5705).
# Warnung: Extreme Werte für Kante (8229, 4643).
# Warnung: Extreme Werte für Kante (4470, 4477).
# Warnung: Extreme Werte für Kante (5843, 5845).
# Warnung: Extreme Werte für Kante (5845, 4471).
# Warnung: Extreme Werte für Kante (432, 5832).
# Warnung: Extreme Werte für Kante (432, 5833).
# Warnung: Extreme Werte für Kante (432, 5834).
# Warnung: Extreme Werte für Kante (432, 5835).
# Warnung: Extreme Werte für Kante (2726, 161).
# Warnung: Extreme Werte für Kante (5539, 5833).
# Warnung: Extreme Werte für Kante (5539, 5834).
# Warnung: Extreme Werte für Kante (7068, 6675).
# Warnung: Extreme Werte für Kante (2909, 1426).
# Warnung: Extreme Werte für Kante (2918, 2919).
# Warnung: Extreme Werte für Kante (6197, 7918).
# Warnung: Extreme Werte für Kante (6197, 6423).
# Warnung: Extreme Werte für Kante (6197, 7923).
# Warnung: Extreme Werte für Kante (6197, 7933).
# Warnung: Extreme Werte für Kante (6450, 6083).
# Warnung: Extreme Werte für Kante (1970, 1966).
# Warnung: Extreme Werte für Kante (6468, 6173).
# Warnung: Extreme Werte für Kante (6983, 5712).
# Warnung: Extreme Werte für Kante (2378, 2366).
# Warnung: Extreme Werte für Kante (2378, 7302).
# Warnung: Extreme Werte für Kante (2378, 2402).
# Warnung: Extreme Werte für Kante (2402, 2361).
# Warnung: Extreme Werte für Kante (2402, 2382).
# Warnung: Extreme Werte für Kante (2393, 2361).
# Warnung: Extreme Werte für Kante (2361, 2382).
# Warnung: Extreme Werte für Kante (2391, 8243).
# Warnung: Extreme Werte für Kante (2391, 2404).
# Warnung: Extreme Werte für Kante (6423, 7923).
# Warnung: Extreme Werte für Kante (6484, 7855).
# Warnung: Extreme Werte für Kante (6484, 6492).
# Warnung: Extreme Werte für Kante (3052, 3060).
# Warnung: Extreme Werte für Kante (3052, 3014).
# Warnung: Extreme Werte für Kante (3052, 213).
# Warnung: Extreme Werte für Kante (3052, 3049).
# Warnung: Extreme Werte für Kante (3069, 3132).
# Warnung: Extreme Werte für Kante (3069, 3020).
# Warnung: Extreme Werte für Kante (3069, 3016).
# Warnung: Extreme Werte für Kante (205, 213).
# Warnung: Extreme Werte für Kante (205, 2995).
# Warnung: Extreme Werte für Kante (205, 2996).
# Warnung: Extreme Werte für Kante (2352, 2353).
# Warnung: Extreme Werte für Kante (2352, 2344).
# Warnung: Extreme Werte für Kante (2352, 2346).
# Warnung: Extreme Werte für Kante (2352, 2349).
# Warnung: Extreme Werte für Kante (2352, 2522).
# Warnung: Extreme Werte für Kante (2355, 2724).
# Warnung: Extreme Werte für Kante (2355, 2723).
# Warnung: Extreme Werte für Kante (2355, 161).
# Warnung: Extreme Werte für Kante (2355, 2725).
# Warnung: Extreme Werte für Kante (2355, 2349).
# Warnung: Extreme Werte für Kante (2355, 2344).
# Warnung: Extreme Werte für Kante (2522, 2353).
# Warnung: Extreme Werte für Kante (2522, 2344).
# Warnung: Extreme Werte für Kante (2522, 2346).
# Warnung: Extreme Werte für Kante (2522, 2349).
# Warnung: Extreme Werte für Kante (2522, 161).
# Warnung: Extreme Werte für Kante (2522, 2725).
# Warnung: Extreme Werte für Kante (2346, 2353).
# Warnung: Extreme Werte für Kante (2346, 2344).
# Warnung: Extreme Werte für Kante (2346, 2358).
# Warnung: Extreme Werte für Kante (2346, 2349).
# Warnung: Extreme Werte für Kante (2346, 2725).
# Warnung: Extreme Werte für Kante (2346, 161).
# Warnung: Extreme Werte für Kante (2344, 2353).
# Warnung: Extreme Werte für Kante (2344, 2725).
# Warnung: Extreme Werte für Kante (2344, 161).
# Warnung: Extreme Werte für Kante (2344, 2349).
# Warnung: Extreme Werte für Kante (2725, 2349).
# Warnung: Extreme Werte für Kante (2725, 161).
# Warnung: Extreme Werte für Kante (161, 2724).
# Warnung: Extreme Werte für Kante (161, 2353).
# Warnung: Extreme Werte für Kante (161, 2343).
# Warnung: Extreme Werte für Kante (161, 2349).
# Warnung: Extreme Werte für Kante (161, 2723).
# Warnung: Extreme Werte für Kante (2349, 2353).
# Warnung: Extreme Werte für Kante (2349, 2342).
# Warnung: Extreme Werte für Kante (2724, 2723).
# Warnung: Extreme Werte für Kante (2724, 2358).
# Warnung: Extreme Werte für Kante (8180, 612).
# Warnung: Extreme Werte für Kante (4469, 4471).
# Warnung: Extreme Werte für Kante (4469, 4609).
# Warnung: Extreme Werte für Kante (8231, 8232).
# Warnung: Extreme Werte für Kante (7473, 7484).
# Warnung: Extreme Werte für Kante (7477, 7483).
# Warnung: Extreme Werte für Kante (737, 3225).
# Warnung: Extreme Werte für Kante (3275, 1578).
# Warnung: Extreme Werte für Kante (473, 6432).
# Warnung: Extreme Werte für Kante (473, 6433).
# Warnung: Extreme Werte für Kante (4589, 6377).
# Warnung: Extreme Werte für Kante (2213, 2217).
# Warnung: Extreme Werte für Kante (8307, 8299).
# Warnung: Extreme Werte für Kante (8307, 8305).
# Warnung: Extreme Werte für Kante (8305, 8304).
# Warnung: Extreme Werte für Kante (1631, 2943).
# Warnung: Extreme Werte für Kante (1631, 523).
# Warnung: Extreme Werte für Kante (213, 3073).
# Warnung: Extreme Werte für Kante (213, 2995).
# Warnung: Extreme Werte für Kante (3026, 6202).
# Warnung: Extreme Werte für Kante (7767, 7775).
# Warnung: Extreme Werte für Kante (6202, 6195).
# Warnung: Extreme Werte für Kante (626, 7305).
# Warnung: Extreme Werte für Kante (6206, 6209).
# Warnung: Extreme Werte für Kante (8236, 8230).
# Warnung: Extreme Werte für Kante (3060, 3132).
# Warnung: Extreme Werte für Kante (3060, 3049).
# Warnung: Extreme Werte für Kante (5538, 5545).
# Warnung: Extreme Werte für Kante (5545, 5663).
# Warnung: Extreme Werte für Kante (1973, 1972).
# Warnung: Extreme Werte für Kante (6177, 6179).
# Warnung: Extreme Werte für Kante (6182, 5815).
# Warnung: Extreme Werte für Kante (5688, 6649).
# Warnung: Extreme Werte für Kante (5572, 5720).
# Warnung: Extreme Werte für Kante (5572, 2279).
# Warnung: Extreme Werte für Kante (5572, 5819).
# Warnung: Extreme Werte für Kante (6996, 7004).
# Warnung: Extreme Werte für Kante (6996, 6999).
# Warnung: Extreme Werte für Kante (2197, 2217).
# Warnung: Extreme Werte für Kante (2197, 2210).
# Warnung: Extreme Werte für Kante (7918, 7926).
# Warnung: Extreme Werte für Kante (7923, 7933).
# Warnung: Extreme Werte für Kante (1876, 2943).
# Warnung: Extreme Werte für Kante (5101, 6133).
# Warnung: Extreme Werte für Kante (1972, 1962).
# Warnung: Extreme Werte für Kante (3016, 5834).
# Warnung: Extreme Werte für Kante (3016, 3020).
# Warnung: Extreme Werte für Kante (3046, 3014).
# Warnung: Extreme Werte für Kante (4371, 4368).
# Warnung: Extreme Werte für Kante (5471, 5720).
# Warnung: Extreme Werte für Kante (5471, 6135).
# Warnung: Extreme Werte für Kante (393, 5218).
# Warnung: Extreme Werte für Kante (7128, 7077).
# Warnung: Extreme Werte für Kante (3235, 2905).
# Warnung: Extreme Werte für Kante (3235, 7591).
# Warnung: Extreme Werte für Kante (3235, 2945).
# Warnung: Extreme Werte für Kante (7591, 2945).
# Warnung: Extreme Werte für Kante (6989, 6988).
# Warnung: Extreme Werte für Kante (6989, 523).
# Warnung: Extreme Werte für Kante (2217, 2210).
# Warnung: Extreme Werte für Kante (6657, 6566).
# Warnung: Extreme Werte für Kante (6657, 2943).
# Warnung: Extreme Werte für Kante (3049, 219).
# Warnung: Extreme Werte für Kante (3006, 1045).
# Warnung: Extreme Werte für Kante (3058, 1045).
# Warnung: Extreme Werte für Kante (3014, 3055).
# Warnung: Extreme Werte für Kante (3132, 219).
# Warnung: Extreme Werte für Kante (5834, 3055).
# Warnung: Extreme Werte für Kante (3020, 3055).
# Warnung: Extreme Werte für Kante (6356, 650).
# Warnung: Extreme Werte für Kante (6356, 6501).
# Warnung: Extreme Werte für Kante (6501, 6492).
# Warnung: Extreme Werte für Kante (4103, 4118).
# Warnung: Extreme Werte für Kante (1958, 1962).
# Warnung: Extreme Werte für Kante (5449, 7441).
# Warnung: Extreme Werte für Kante (523, 6988).
# Warnung: Extreme Werte für Kante (614, 8185).
# Warnung: Extreme Werte für Kante (614, 8186).
# Warnung: Extreme Werte für Kante (2210, 2206).
# Warnung: Extreme Werte für Kante (4434, 4438).
# Warnung: Extreme Werte für Kante (8242, 8244).
# Warnung: Extreme Werte für Kante (1277, 7005).
# Warnung: Extreme Werte für Kante (1277, 1280).
# Warnung: Extreme Werte für Kante (6990, 7002).
# Warnung: Extreme Werte für Kante (6563, 4452).
# Warnung: Extreme Werte für Kante (4452, 4451).
# Warnung: Extreme Werte für Kante (3059, 3066).
# Warnung: Extreme Werte für Kante (6224, 1574).
# Warnung: Extreme Werte für Kante (2200, 2201).
# Warnung: Extreme Werte für Kante (2200, 2206).
# Warnung: Extreme Werte für Kante (7149, 7142).
# Warnung: Extreme Werte für Kante (6482, 477).
# Warnung: Extreme Werte für Kante (477, 1037).
# Warnung: Extreme Werte für Kante (2810, 2627).
# Warnung: Extreme Werte für Kante (2201, 2206).
# Warnung: Extreme Werte für Kante (5720, 7651).
# Warnung: Extreme Werte für Kante (4362, 4372).
# Warnung: Extreme Werte für Kante (4362, 4366).
# Warnung: Extreme Werte für Kante (4366, 4372).
# Warnung: Extreme Werte für Kante (454, 6028).
# Warnung: Extreme Werte für Kante (1555, 1556).
# Berechnung der Laplace-Matrix...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/sparse/csgraph/_laplacian.py:470: RuntimeWarning: invalid value encountered in sqrt
#   w = np.where(isolated_node_mask, 1, np.sqrt(w))
# Berechnung der Eigenwerte und Eigenvektoren...
# Clustering der Benutzer...
# Berechnung der Degree Centrality...
# Auswahl der Impfkandidaten...
# Ausgewählte Knoten gespeichert: 990 Knoten.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 106
#     103 print(f"Ausgewählte Knoten gespeichert: {len(selected_nodes)} Knoten.")
#     105 # Visualisierung
# --> 106 pos = nx.spring_layout(G, seed=42)
#     107 colors = ['red' if node in selected_nodes else 'blue' for node in G.nodes()]
#     108 plt.figure(figsize=(12, 8))
#
# File <class 'networkx.utils.decorators.argmap'> compilation 12:4, in argmap_spring_layout_9(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/drawing/layout.py:483, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     481         nnodes, _ = A.shape
#     482         k = dom_size / np.sqrt(nnodes)
# --> 483     pos = _sparse_fruchterman_reingold(
#     484         A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     485     )
#     486 except ValueError:
#     487     A = nx.to_numpy_array(G, weight=weight)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 20:4, in argmap__sparse_fruchterman_reingold_17(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/networkx/drawing/layout.py:626, in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     622     Ai = A.getrowview(i).toarray()  # TODO: revisit w/ sparse 1D container
#     623     # displacement "force"
#     624     displacement[:, i] += (
#     625         delta * (k * k / distance**2 - Ai * distance / k)
# --> 626     ).sum(axis=1)
#     627 # update positions
#     628 length = np.sqrt((displacement**2).sum(axis=0))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/_methods.py:50, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _amin(a, axis=None, out=None, keepdims=False,
#      47           initial=_NoValue, where=True):
#      48     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
#      52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      54 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      55           initial=_NoValue, where=True):
#
# KeyboardInterrupt:
